# %%
import sys
# Desinstalamos primero para asegurar limpieza y reinstalamos con dependencias completas
# !{sys.executable} -m pip uninstall -y plotly
# !{sys.executable} -m pip install plotly==5.18.0 nbformat --user
# Out:
# Found existing installation: plotly 5.18.0
# Uninstalling plotly-5.18.0:
#   Successfully uninstalled plotly-5.18.0
# ...
#   Using cached plotly-5.18.0-py3-none-any.whl (15.6 MB)
# ...
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
try:
    from plotly import graph_objects as go
    print("🚀 ¡LOGRADO! Plotly cargado correctamente.")
except ImportError as e:
    print(f"❌ Error: {e}")
    import sys
    print(f"Buscando en: {sys.path}")
# Out:
# 🚀 ¡LOGRADO! Plotly cargado correctamente.
