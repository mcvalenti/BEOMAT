# %%
import os
import sys
from space_env import Satellite, Propagator

print("Entorno cargado correctamente.")
# Out:
# >>> [SUCCESS] Motor GMAT cargado y configurado.
# Entorno cargado correctamente.

# %%
import sys
# !{sys.executable} -m pip install --upgrade nbformat
# Out:
# Collecting nbformat
#   Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
# Requirement already satisfied: traitlets>=5.1 in c:\users\macec\git\beomat\beomat\.venv\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\macec\git\beomat\beomat\.venv\lib\site-packages (from nbformat) (5.8.1)
# Collecting jsonschema>=2.6
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Collecting fastjsonschema>=2.15
#   Downloading fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\macec\git\beomat\beomat\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (6.4.5)
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Collecting attrs>=22.2.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.20.1-cp38-none-win_amd64.whl (218 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\macec\git\beomat\beomat\.venv\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat) (3.20.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\macec\git\beomat\beomat\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\macec\git\beomat\beomat\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (311)
# Installing collected packages: rpds-py, attrs, referencing, pkgutil-resolve-name, jsonschema-specifications, jsonschema, fastjsonschema, nbformat
# Successfully installed attrs-25.3.0 fastjsonschema-2.21.2 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 nbformat-5.10.4 pkgutil-resolve-name-1.3.10 referencing-0.35.1 rpds-py-0.20.1
# WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\Users\macec\git\BEOMAT\BEOMAT\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
from gmat_env import get_gmat
gmat = get_gmat

# %%
gmat
# Out:
# <function gmat_env.get_gmat()>

# %%
try:
    import gmatpy as gmat
    
    # Inicializacion global
    gmat.Setup(startup_file) 
    
    # Para acceder a la interfaz y crear objetos:
    # Nota:GmatInterface or usas gmat.Construct 
    print("Motor de GMAT cargado correctamente.")
    
    # Crear un satelite
    sat = gmat.Construct("Spacecraft", "Cubesat_EO")
    print(f"Objeto creado: {sat.GetName()}")
    
except Exception as e:
    print(f"Error detallado: {e}")
# Out:
# Error detallado: name 'startup_file' is not defined
